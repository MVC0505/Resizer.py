# %% [markdown]
# <a href="https://colab.research.google.com/github/MVC0505/Resizer.py/blob/main/Resizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from PIL import Image

# Input and output folders
INPUT_FOLDER = "input_images"
OUTPUT_FOLDER = "output_images"

# Desired size (width, height)
NEW_SIZE = (800, 600)  # Change as needed

def resize_images():
    # Create output folder if it doesn't exist
    if not os.path.exists(OUTPUT_FOLDER):
        os.makedirs(OUTPUT_FOLDER)

    # Process each image
    for filename in os.listdir(INPUT_FOLDER):
        if filename.lower().endswith((".png", ".jpg", ".jpeg")):
            img_path = os.path.join(INPUT_FOLDER, filename)
            img = Image.open(img_path)

            original_size = img.size  # (width, height)

            # Resize image
            img_resized = img.resize(NEW_SIZE)

            resized_size = img_resized.size

            # Save output
            output_path = os.path.join(OUTPUT_FOLDER, filename)
            img_resized.save(output_path)

            print(f"Processed: {filename}")
            print(f" Original Size: {original_size}")
            print(f" Resized Size: {resized_size}\n")

    print("All images have been resized successfully!")

if __name__ == "__main__":
    resize_images()
# Out:
# Processed: img1.png
#  Original Size: (500, 500)
#  Resized Size: (800, 600)
#
# Processed: img3.png
#  Original Size: (408, 612)
#  Resized Size: (800, 600)
#
# Processed: img4.png
#  Original Size: (408, 612)
#  Resized Size: (800, 600)
#
# Processed: img2.png
#  Original Size: (612, 408)
#  Resized Size: (800, 600)
#
# All images have been resized successfully!
